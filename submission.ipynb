# %%
import pandas as pd
from src.heatmap import plot_player_heatmap
from src.sprint_map import plot_sprint_map

# %%
df=pd.read_csv("data/synced_enriched_tracking_and_events_10min.csv")
# Out:
# /var/folders/r5/bx2jhb6n64n4zm91gw712nr00000gn/T/ipykernel_19591/518834114.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("data/synced_enriched_tracking_and_events_10min.csv")

# %%
df.columns
# Out:
# Index(['x', 'y', 'player_id_tracking', 'is_detected', 'frame', 'timestamp',
#        'period', 'possession_player_id', 'possession_group', 'ball_x',
#        'ball_y', 'ball_z', 'is_detected_ball', 'match_id', 'start_time',
#        'end_time', 'match_name', 'date_time', 'home_team.name',
#        'away_team.name', 'id', 'short_name', 'number', 'team_id_tracking',
#        'team_name', 'player_role.position_group', 'total_time',
#        'player_role.name', 'player_role.acronym', 'is_gk',
#        'direction_player_1st_half', 'direction_player_2nd_half', 'event_id',
#        'player_id_event', 'frame_start', 'frame_end', 'event_type',
#        'team_id_event', 'player_in_possession_id', 'x_start', 'y_start',
#        'x_end', 'y_end', 'runner', 'ball_carrier', 'tip'],
#       dtype='object')

# %%
df.shape
# Out:
# (127358, 46)

# %%
plot_player_heatmap(df, player_id=12345)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plot_player_heatmap(df, player_id=12345)
#
# File ~/football-data-analytics/skill_corner_cup/analytics_cup_analyst/src/heatmap.py:39, in plot_player_heatmap(df, player_id)
#      36 ax.set_title(f"{player_name} ({position}) - {team}\nHeat Map", color='white', fontsize=16)
#      38 plt.tight_layout()
# ---> 39 plt.savefig(f'heatmap_{player_name.replace(" ", "_")}.png', dpi=150, facecolor='#1a1a1a')
#      40 plt.show()
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
plot_sprint_map(df, player_id=12345)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 plot_sprint_map(df, player_id=12345)
#
# File ~/football-data-analytics/skill_corner_cup/analytics_cup_analyst/src/sprint_map.py:57, in plot_sprint_map(df, player_id)
#      54 ax.legend(loc='upper right', facecolor='#001400', edgecolor='white', labelcolor='white')
#      56 plt.tight_layout()
# ---> 57 plt.savefig(f'sprint_map_{player_name.replace(" ", "_")}.png', dpi=150, facecolor='#1a1a1a')
#      58 plt.show()
#
# AttributeError: 'int' object has no attribute 'replace'

# %%
df_10min.tail()
# Out:
#            x     y  player_id  is_detected  frame               timestamp  \
# 538280  6.97  8.46      33697         True   6006 2025-12-26 00:09:59.600
# 538281  7.40  8.34      33697         True   6007 2025-12-26 00:09:59.700
# 538282  7.82  8.22      33697         True   6008 2025-12-26 00:09:59.800
# 538283  8.25  8.08      33697         True   6009 2025-12-26 00:09:59.900
# 538284  8.66  7.94      33697         True   6010 2025-12-26 00:10:00.000
#
#         period  possession_player_id possession_group  ball_x  ...  number  \
# 538280     1.0               51667.0        home team    5.51  ...       4
# 538281     1.0               51667.0        home team    5.78  ...       4
# 538282     1.0               51667.0        home team    6.06  ...       4
# 538283     1.0                   NaN        home team    6.34  ...       4
# 538284     1.0                   NaN        home team    6.69  ...       4
#
#         team_id    team_name  player_role.position_group total_time  \
# 538280     4177  Auckland FC            Central Defender       5400
# 538281     4177  Auckland FC            Central Defender       5400
# 538282     4177  Auckland FC            Central Defender       5400
# 538283     4177  Auckland FC            Central Defender       5400
# 538284     4177  Auckland FC            Central Defender       5400
#
#         player_role.name player_role.acronym  is_gk direction_player_1st_half  \
# 538280  Left Center Back                 LCB  False             right_to_left
# 538281  Left Center Back                 LCB  False             right_to_left
# 538282  Left Center Back                 LCB  False             right_to_left
# 538283  Left Center Back                 LCB  False             right_to_left
# 538284  Left Center Back                 LCB  False             right_to_left
#
#        direction_player_2nd_half
# 538280             left_to_right
# 538281             left_to_right
# 538282             left_to_right
# 538283             left_to_right
# 538284             left_to_right
#
# [5 rows x 32 columns]
